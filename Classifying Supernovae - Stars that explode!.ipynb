# %% [markdown]
# # <span style="color:purple"> Welcome to Classifying Supernovae - Stars the Explode! </span>
# #### By Yssa Camacho-Neves
#
#
# #### This interactive program is aimed for students between 6th and 12th grade.
# *All spectra sourced from [Open Supernova Catalog](https://sne.space/)*

# %% [markdown]
# ### Let's begin by introducing supernovae.
#
# ### Supernovae are NOT stars. A supernova is what happens after a star explodes. It is made up of gas and dust.
#
# ![](CasASupernova.jpg)

# %% [markdown]
# # <span style="color:purple"> How can we see supernovae? </span>
#
#
# ### Supernovae light comes to us from millions of light years away, meaning that the original stars exploded millions of years ago!
#
# ### Telescopes on Earth and in space collect the light emitted by the supernova.
#
# ![title](salt-telescope.jpg)
#
# ### Astronomers like me will then take the light from the telescope and study it to find out what the supernova is made of and how it exploded.

# %% [markdown]
# # <span style="color:purple"> What do astronomers see? </span>
#
# ![](prism.gif)
#
# ![](hydrogenheliumspectra.jpg)
#
# ## Converting colors to numbers
# ![](colortonm.jpg)

# %% [markdown]
# # <span style="color:purple"> Different types of Supernovae </span>
#
# ![](sn_types.jpg)
#
# ## 1) Core Collapse Supernova happen when massive stars (at least 8 times more massive than our Sun!) run out of fuel and "die"
#
#
# ## 2) Thermonuclear Supernova happens when a small star (White Dwarf) gains too much gas from a nearby companion and becomes unstable
#
# ![](SNIa.jpg)

# %% [markdown]
# # Ok! Let's start coding to classify some supernova!

# %%
# We need some of these programs to help us make our plots!

import os
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## We need to load and plot our ideal models
# ### There are 3 models we will use model_Ia, model_Ic, and model_IIP
#
# #### This is how we load up our models
#
# ```wavelength, brightness = np.genfromtxt('model_XX', unpack=True)```

# %%
# Load model_Ia

wavelength_Ia, brightness_Ia = np.genfromtxt('model_Ia', unpack=True)

# %%
# Load model_Ic

# %%
# Load model_IIP

# %% [markdown]
# # Great job!
# ## Now we need to plot them
#
# #### This is how we plot up our models
#
# ```plt.plot(wavelength, brightness, label= 'model_XX', color='blue')
# plt.legend()
# plt.show()```

# %%
#Plot model_Ia

plt.plot(wavelength_Ia, brightness_Ia, label= 'model_Ia', color='blue') 
plt.legend()
plt.show()

# %%
#Plot model_Ic 
#HINT: Try using a different color

# %%
#Plot model_IIP
#HINT: Try using a different color

# %% [markdown]
# # Awesome work!
# ## Now we need to load and plot our 5 unknown supernovae spectra
#
# To load:
#
# ```wavelength, brightness = np.genfromtxt('supernovaeX', unpack=True)```
#
# To plot:
#
# ```plt.plot(wavelength, brightness, label= 'supernovaeX', color='blue')
# plt.legend()
# plt.show()```

# %%
# Load and plot supernovae1

wavelength1, brightness1 = np.genfromtxt('supernovae1', unpack=True)
    
plt.plot(wavelength1, brightness1, label='supernovae1', color='black')
plt.legend()
plt.show()

# %% [markdown]
# ## Can you guess what type of supernovae this is based on the model plots?
#
# Astronomers like to double check so let's double check by overplotting everything!
#
# Use all the plots you made so far and put them all in the same cell

# %%
# Double checking the type of supernovae1

# %%
# Load and plot supernovae2

# %%
# Double checking the type of supernovae2

# %%
# Load and plot supernovae3

# %%
# Double checking the type of supernovae3

# %%
# Load and plot supernovae4

# %%
# Double checking the type of supernovae4

# %%
# Load and plot supernovae5

# %%
# Double checking the type of supernovae5
